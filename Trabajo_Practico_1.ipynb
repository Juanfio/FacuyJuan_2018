# %%
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data
AP_MS = ldata ("yeast_AP-MS.txt")

#Punto 1.b.i y 1.b.ii
def num_nod_edges(archive):
    data=ldata(archive)
    g = nx.Graph ()
    nod_edges = []
    for i in range (len(data)):
        g.add_nodes_from (data[i])
        g.add_edge (data[i][0],data[i][1])
    N=g.number_of_nodes()
    L=g.number_of_edges()
    nod_edges.append (N)
    nod_edges.append (L)
    return nod_edges

#Punto 1.b.v
densidad_red = (num_prueba [1] *2)/(num_prueba[0]*(num_prueba[0] -1))
#


                          
g = nx.Graph ()

for i in range (len(AP_MS)):
    g.add_nodes_from (AP_MS[i])
    g.add_edge (AP_MS[i][0],AP_MS[i][1])
    
nx.draw(g, with_labels=False, font_weight='bold')
plt.show ()

# %%
#Para hacer tablas
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

tabla_red = pd.DataFrame ({"Redes":[1,2,3],
                             "Num_Nodos":["John","Jim","Jane"],
                             "Num_Enlaces":[False,False,True],
                             "Dirigida":[22,33,44],
                             "Densidad_Red":[0,0,3],
                            "Coef_de_Clus":[0,0,0],
                          })

print (tabla_red)
# Out:
#    Coef_de_Clus  Densidad_Red  Dirigida Num_Enlaces Num_Nodos  Redes
# 0             0             0        22       False      John      1
# 1             0             0        33       False       Jim      2
# 2             0             3        44        True      Jane      3

# %%
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

def num_nod_edges(archive):
    data=ldata(archive)
    g = nx.Graph ()
    nod_edges = []
    for i in range (len(data)):
        g.add_nodes_from (data[i])
        g.add_edge (data[i][0],data[i][1])
    N=g.number_of_nodes()
    L=g.number_of_edges()
    nod_edges.append (N)
    nod_edges.append (L)
    return nod_edges

num_prueba = num_nod_edges ("yeast_AP-MS.txt")
print (num_prueba)

densidad_red = (num_prueba [1] *2)/(num_prueba[0]*(num_prueba[0] -1))
print (densidad_red)
# Out:
# [1622, 9070]
# 0.006899274397150227
