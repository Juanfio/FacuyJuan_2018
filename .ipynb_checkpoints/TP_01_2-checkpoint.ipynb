# %%
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

g = nx.read_gml('dolphins.gml')  #lee el gml

plt.subplot(321) #los subplot(fila,columna,lugar) tienen que ir antes del nx.draw
nx.draw_random(g, node_size = 40,with_labels=False, font_weight='bold')
#Asignar colores pos, cmap=plt.get_cmap('plasma'), node_color=list(dict(g.degree).values()),
plt.subplot(322)
nx.draw_circular(g, node_size = 40,with_labels=False, font_weight='bold')

plt.subplot(323)
nx.draw_spectral(g,node_size = 40,with_labels=False, font_weight='bold')

plt.subplot(324)
nx.draw_shell(g, node_size = 40,with_labels=False, font_weight='bold')

plt.subplot(325)
nx.draw_circular(g, node_size = 40,with_labels=False, font_weight='bold') #dibuja el grafo almacenado en la variable g

plt.show ()

# %%
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import random as rm

def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

delfines_generos = ldata ("dolphinsGender.txt")
delfines = []
generos = []
for i in range (len(delfines_generos)): #Separe en dos listas: 1) los nombres de los delfines// 2)sus generos
    delfines.append(delfines_generos[i][0])
    generos.append(delfines_generos[i][1])

for i in range (N):
    gen_aleatorio = rm.choice (("m","f","NA"))
    G.node[i]["Genero"] = gen_aleatorio
    print (G.node[i])
    
    
    
    
    
g = nx.read_gml('dolphins.gml')  #lee el gml
nx.draw_spectral(g, node_size = 100,with_labels=False, font_weight='bold')
N = g.number_of_nodes()
L = g.number_of_edges()


#print(g.node["Five"])
plt.show ()
# Out:
# ['Five', 'Cross', 'SMN5', 'MN83', 'Trigger', 'Patchback', 'Vau', 'Fork', 'TR120', 'MN105', 'Haecksel', 'MN60', 'Stripes', 'Jonah', 'TSN103', 'Topless', 'Scabs', 'TR99', 'Shmuddel', 'TSN83', 'Grin', 'Zap', 'SN9', 'SN4', 'SN63', 'Hook', 'Whitetip', 'Kringel', 'Zipfel', 'SN89', 'SN100', 'Double', 'CCL', 'Thumper', 'Beak', 'Fish', 'Oscar', 'TR77', 'SN96', 'Bumper', 'PL', 'TR82', 'DN16', 'Web', 'SN90', 'Beescratch', 'Wave', 'Feather', 'Gallatin', 'Upbang', 'DN63', 'DN21', 'Jet', 'Number1', 'Knit', 'Zig', 'Ripplefluke', 'MN23', 'Quasi', 'Mus', 'Notch', 'TR88']
# ['f', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'f', 'f', 'f', 'NA', 'm', 'NA', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'm', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'NA', 'f', 'm', 'm', 'm', 'f', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'NA', 'm', 'm', 'm', 'm', 'f']
# 62
# 159
# ...

# %%
import random as rm
pru = rm.choice((True, False, 0))
print (pru)
# Out:
# True

# %%
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import random as rm

G = nx.Graph()

for i in range (4):
    G.add_node(i)
    G.add_edge(i,i+1)

N = G.number_of_nodes()
L = G.number_of_edges()
for i in range (N):
    gen_aleatorio = rm.choice (("m","f","NA"))
    G.node[i]["Genero"] = gen_aleatorio
    print (G.node[i])
    #if algo == m:
        #mandar el color

#gen_aleatorio = rm.choice (("m","f","NA"))
#print (gen_aleatorio)
#G.node[1]["Genero"] = gen_aleatorio
#print (G.node [1])
nx.draw (G)
plt.show ()
# Out:
# {'Genero': 'NA'}
# {'Genero': 'NA'}
# {'Genero': 'm'}
# {'Genero': 'f'}
# {'Genero': 'm'}

# %%
import networkx as nx
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import random as rm

def ldata(archive):
    f=open(archive)
    data=[]
    for line in f:
        line=line.strip()
        col=line.split()
        data.append(col)
    return data

delfines_generos = ldata ("dolphinsGender.txt")
delfines = []
generos = []
for i in range (len(delfines_generos)): #Separe en dos listas: 1) los nombres de los delfines// 2)sus generos
    delfines.append(delfines_generos[i][0])
    generos.append(delfines_generos[i][1])

print (generos)
#for i in range (N):
gen_aleatorio = np.random.shuffle(generos)
    #G.node[i]["Genero"] = gen_aleatorio
    #print (G.node[i])
print (gen_aleatorio)
# Out:
# ['f', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'f', 'm', 'f', 'm', 'f', 'f', 'f', 'NA', 'm', 'NA', 'f', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'f', 'f', 'm', 'm', 'f', 'm', 'f', 'm', 'm', 'm', 'NA', 'f', 'm', 'm', 'm', 'f', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'm', 'NA', 'm', 'm', 'm', 'm', 'f']
# None

# %%
rm.shuffle(generos)

# %%
generos
# Out:
# ['m',
#  'NA',
#  'm',
#  'm',
#  'm',
#  'f',
#  'm',
#  'f',
#  'f',
#  'm',
#  'm',
#  'm',
#  'm',
#  'm',
#  'f',
#  'm',
#  'f',
#  'm',
#  'f',
#  'f',
#  'm',
#  'f',
#  'm',
#  'f',
#  'm',
#  'f',
#  'f',
#  'f',
#  'm',
#  'm',
#  'm',
#  'f',
#  'f',
#  'm',
#  'm',
#  'NA',
#  'm',
#  'm',
#  'm',
#  'f',
#  'm',
#  'f',
#  'f',
#  'm',
#  'm',
#  'm',
#  'f',
#  'm',
#  'f',
#  'f',
#  'm',
#  'm',
#  'm',
#  'f',
#  'm',
#  'm',
#  'f',
#  'f',
#  'NA',
#  'NA',
#  'm',
#  'f']

# %%
Para el 2.b.i:
    *Hace un for que se repita 1000 veces, otro for dentro que recorra los elementos de la lista genero y delfines
    *(en cada vuelta asigna al primer elemento de la lista de los delfines un elemento de la lista de los generos)
    *Cuando se termina el segundo for se asignaron nuevos generos a todos los delfines. G.node[delfines[i]][genero] = genero[i]
    *Se conservan los enlaces entre los delfines.
    *BUSCAR: alguna funcion que mire atributos del nodo y mire cuantos nodos con el mismo genero estan unidos.
    * Se vuelve al primer for, se hace todo 1000 veces y se promedia.
